# %%
class Point: # template
    def __init__(self, a = 0, b = 0): # parameters
        self.x = a
        self.y = b

    def translate(self, dx, dy):
        self.x += dx
        self.y += dy

    def odistance(self):
        import math
        d = math.sqrt(self.x ** 2 + self.y ** 2)

# %%
import time
time.perf_time()
p = Point(3,4)
q = Point(7,10)
time.perf_time()

# %%
print(p)
# Out:
# <__main__.Point object at 0x000001E0AD614440>

# %%
# import math
# class Point:
#     def __init__(self, a = 0, b = 0): # constructor
#         self.r = math.sqrt(a**2 + b**2)
#         if a == 0: self.theta = math.pi/2
#         else: self.theta = math.atan(b/a) # gives (r, theta) form of point

#     def odistance(self):
#         return self.r # ez
    
#     def translate(self, dx, dy):
#         x = self.r*math.cos(self.theta)
#         y = self.r*math.sin(self.theta)

#         x += dx
#         y += dy

#         self.r = math.sqrt(x**2+y**2)
#         if x == 0: self.theta = math.pi/2
#         else: self.theta = math.atan(y/x) # gives (r, theta) form of point

#     def __str__(self):
#         return(
#             '(' + str(self.x) + ',' + str(self.y) + ')'
#         )
    
#     def __add__(self,p):
#         return Point(self.x + p.x, self.y + p.y)
    
class Point: # template
    def __init__(self, a = 0, b = 0): # parameters
        self.x = a
        self.y = b

    def translate(self, dx, dy):
        self.x += dx
        self.y += dy

    def odistance(self):
        import math
        d = math.sqrt(self.x ** 2 + self.y ** 2)
    
    def __str__(self):
        return(
            '(' + str(self.x) + ',' + str(self.y) + ')'
        )
    
    def __add__(self,p):
        return Point(self.x + p.x, self.y + p.y)

# %%
p = Point(3,4)
q = Point(7,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 import time
# ----> 2 time.perf_time()
#       3 p = Point(3,4)
#       4 q = Point(7,10)
#
# AttributeError: module 'time' has no attribute 'perf_time'

# %%
print(p)
# Out:
# <__main__.Point object at 0x000001E0AD614830>

# %%
print(p.odistance())
# Out:
# 5.0

# %%
p.r, p.theta
# Out:
# (5.0, 0.9272952180016122)

# %%
print(p+q)
# Out:
# (10,14)
